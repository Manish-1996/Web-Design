# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('/home/manish/Downloads/Exigent2.csv')
df.head()
# Out:
#                  Header                         Key Picked  \
# 0  BUSINESS AND PURPOSE                Affiliates included
# 1  BUSINESS AND PURPOSE                  Client Legal Name
# 2  BUSINESS AND PURPOSE            Counterparty Legal Name
# 3  BUSINESS AND PURPOSE  Products, Services or Combination
# 4  BUSINESS AND PURPOSE     Subject Matter of the Contract
#
#    Total Value Count (for Hybrid procurement, Hybrid procurement -copy, Hybrid procurement - new copy, Hybrid Lease model (close to 300 contracts)  \
# 0                                                454
# 1                                                470
# 2                                                471
# 3                                                472
# 4                                                472
#
#    Yes Count  No Count AccuraAccuracy excluding blank values (7th August)  \
# 0        394        60                                              57.58
# ...

# %%
plt.figure(figsize=(50, 10))
plt.xticks(rotation=90)

x= df['Key Picked']
y1 = df['Sep25']
y2 = df['Oct2']

plt.title('Accurcy vs key picked',fontsize=18)

plt.xlabel('Accuracy', labelpad=14,fontsize=18)
plt.ylabel('Key Picked', labelpad=14,fontsize=18)


plt.plot(x,y1,label='Sep 25')
plt.plot(x,y2, label='oct 2')
plt.legend()
plt.show()
